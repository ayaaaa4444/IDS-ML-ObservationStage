# %%
# ============================================================
# 01 - Exploration du dataset NSL-KDD
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Noms des colonnes du dataset NSL-KDD
columns = [
    "duration", "protocol_type", "service", "flag", "src_bytes",
    "dst_bytes", "land", "wrong_fragment", "urgent", "hot",
    "num_failed_logins", "logged_in", "num_compromised", "root_shell",
    "su_attempted", "num_root", "num_file_creations", "num_shells",
    "num_access_files", "num_outbound_cmds", "is_host_login",
    "is_guest_login", "count", "srv_count", "serror_rate",
    "srv_serror_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate",
    "diff_srv_rate", "srv_diff_host_rate", "dst_host_count",
    "dst_host_srv_count", "dst_host_same_srv_rate", "dst_host_diff_srv_rate",
    "dst_host_same_src_port_rate", "dst_host_srv_diff_host_rate",
    "dst_host_serror_rate", "dst_host_srv_serror_rate", "dst_host_rerror_rate",
    "dst_host_srv_rerror_rate", "label", "difficulty"
]

# Chargement des données
train = pd.read_csv("../data/raw/KDDTrain+.txt", names=columns)
test  = pd.read_csv("../data/raw/KDDTest+.txt",  names=columns)

print("✅ Données chargées avec succès !")
print(f"Train : {train.shape[0]} lignes x {train.shape[1]} colonnes")
print(f"Test  : {test.shape[0]} lignes x {test.shape[1]} colonnes")
# Out:
# ✅ Données chargées avec succès !
# Train : 125973 lignes x 43 colonnes
# Test  : 22544 lignes x 43 colonnes

# %%
# ============================================================
# Aperçu général des données
# ============================================================

# Afficher les 5 premières lignes
print("=== 5 premières lignes ===")
train.head()
# Out:
# === 5 premières lignes ===
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# ...

# %%
# ============================================================
# Types d'attaques présentes dans le dataset
# ============================================================

print("=== Répartition des labels ===")
print(train["label"].value_counts())
# Out:
# === Répartition des labels ===
# label
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
# ============================================================
# Visualisation de la répartition des labels
# ============================================================

# Regrouper en deux catégories : normal vs attaque
train["categorie"] = train["label"].apply(lambda x: "normal" if x == "normal" else "attaque")

# Graphique
plt.figure(figsize=(6, 4))
train["categorie"].value_counts().plot(kind="bar", color=["steelblue", "tomato"])
plt.title("Répartition Normal vs Attaque")
plt.xlabel("Catégorie")
plt.ylabel("Nombre de connexions")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("../results/repartition_normal_attaque.png")
plt.show()

print(f"\n✅ Normal  : {(train['categorie']=='normal').sum()} connexions")
print(f"✅ Attaque : {(train['categorie']=='attaque').sum()} connexions")
# Out:
# ✅ Normal  : 67343 connexions
# ✅ Attaque : 58630 connexions

# %%
# ============================================================
# Informations générales sur le dataset
# ============================================================

print("=== Types des colonnes ===")
print(train.dtypes)

print("\n=== Valeurs manquantes ===")
print(train.isnull().sum().sum(), "valeurs manquantes au total")

print("\n=== Statistiques générales ===")
train.describe()
# Out:
# === Types des colonnes ===
# duration                         int64
# protocol_type                      str
# service                            str
# flag                               str
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# ...

# %%
# ============================================================
# Répartition des protocoles réseau
# ============================================================

plt.figure(figsize=(6, 4))
train["protocol_type"].value_counts().plot(kind="bar", color=["steelblue", "tomato", "green"])
plt.title("Répartition des protocoles réseau")
plt.xlabel("Protocole")
plt.ylabel("Nombre de connexions")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("../results/repartition_protocoles.png")
plt.show()

print(train["protocol_type"].value_counts())
# Out:
# protocol_type
# tcp     102689
# udp      14993
# icmp      8291
# Name: count, dtype: int64

# %%
# ============================================================
# Classification des attaques par familles officielles
# DoS / Probe / R2L / U2R
# ============================================================

# Mapping des 22 attaques vers les 4 familles reconnues
familles_attaques = {
    # DoS - Déni de service
    "neptune": "DoS", "smurf": "DoS", "back": "DoS",
    "teardrop": "DoS", "pod": "DoS", "land": "DoS",

    # Probe - Reconnaissance / scan
    "satan": "Probe", "ipsweep": "Probe", "portsweep": "Probe",
    "nmap": "Probe",

    # R2L - Remote to Local (accès non autorisé distant)
    "warezclient": "R2L", "guess_passwd": "R2L", "warezmaster": "R2L",
    "imap": "R2L", "ftp_write": "R2L", "multihop": "R2L",
    "phf": "R2L", "spy": "R2L",

    # U2R - User to Root (élévation de privilèges)
    "buffer_overflow": "U2R", "rootkit": "U2R",
    "loadmodule": "U2R", "perl": "U2R",

    # Trafic normal
    "normal": "Normal"
}

train["famille"] = train["label"].map(familles_attaques)

print("=== Répartition par famille d'attaque ===")
print(train["famille"].value_counts())
# Out:
# === Répartition par famille d'attaque ===
# famille
# Normal    67343
# DoS       45927
# Probe     11656
# R2L         995
# U2R          52
# Name: count, dtype: int64

# %%
# ============================================================
# Visualisation des familles d'attaques
# ============================================================

plt.figure(figsize=(8, 5))
couleurs = {"Normal": "steelblue", "DoS": "tomato", "Probe": "orange",
            "R2L": "purple", "U2R": "darkred"}
counts = train["famille"].value_counts()
plt.bar(counts.index, counts.values,
        color=[couleurs[f] for f in counts.index])
plt.title("Répartition du trafic par famille d'attaque (NSL-KDD)")
plt.xlabel("Famille")
plt.ylabel("Nombre de connexions")
plt.yscale("log")  # échelle log car U2R est très petit
for i, v in enumerate(counts.values):
    plt.text(i, v * 1.1, str(v), ha="center", fontweight="bold")
plt.tight_layout()
plt.savefig("../results/familles_attaques.png")
plt.show()

print("✅ Graphique sauvegardé dans results/")
# Out:
# ✅ Graphique sauvegardé dans results/
